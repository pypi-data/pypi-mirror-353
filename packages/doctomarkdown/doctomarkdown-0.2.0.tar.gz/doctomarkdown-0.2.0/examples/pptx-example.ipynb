# %% [markdown]
# ## Conversion of PPTx to Markdown/Text

# %%
from doctomarkdown import DocToMarkdown
from openai import OpenAI
import os
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
    api_key=os.environ.get("OPENAI_API_KEY"),
)

app = DocToMarkdown(llm_client=client, 
                    llm_model='gpt-4o')

result = app.convert_pptx_to_markdown(
    filepath="sample_docs/sample_ppt_2.pptx",
    extract_images=True,
    extract_tables=True,
    output_path="markdown_output"
)

for page in result.pages:
    print(f"Page Number: {page.page_number} | Page Content: {page.page_content}")
# Out:
# [INFO] Starting PPTX extraction for: sample_docs/sample_ppt_2.pptx
# Conversion completed: 1 files converted successfully, 0 files failed.
# [SUCCESS] Extraction is successful via LLM for file: sample_docs/sample_ppt_2.pptx
# Page Number: 1 | Page Content:
# # Image to Markdown
#
# **Extraction of Complex PPT Contents (Images) into Markdown**
#
# ---
#
# ## Resume Screening Application Design
#
# ### Icons
# - **O365**
# - **Amazon S3**
# - **SQL**
#
# ### Resumes Directory
# - **No-SQL DB**
#
# ### Batch Processing
# - **PDPTextExtractor Agent**
#
# ### HR Input Parameters
# - **Priority Score: 0-1**
# - **Job Title**
# - **Job Description**
# - **Years of Experience**
# - **Education Qualification**
# - **Skill Set**
#
# ### Prompt Context
# - **Refined Information:**
#   - **YoE**, **Skillset**, **Projects**
#   - **Education Qualification**
#   - **Experience**, **Company Names**
#   - **Quantitively Impacts**
#
# ### VectorDB Embedding Store
# - **OBJECT**
#   - **Key**: **Value**
#   - **Key**: **Value**
#   - **Key**: **Value**
#
# ### Retrieval Agent
# - **Top 20 Matching records**
#
# ### LLM
# - **Re-ranking Algorithm Mechanism**
#   - **Resume Score Generation Based on factors**
#
# ### Top Resumes Selection
#
# ### Future Scope
# - **Profile Summary Extraction Agent**
#
# ---
#
# ## Flowchart Description
#
# The flowchart illustrates a resume screening application design. It includes various components such as:
#
# - **Icons**: Representing different services like O365, Amazon S3, and SQL.
# - **Resumes Directory**: Using a No-SQL database.
# - **Batch Processing**: Managed by the PDPTextExtractor Agent.
# - **HR Input Parameters**: Including priority score, job title, job description, years of experience, education qualification, and skill set.
# - **Prompt Context**: Involves refined information like YoE, skillset, projects, education qualification, experience, company names, and quantitative impacts.
# - **VectorDB Embedding Store**: Contains key-value pairs.
# - **Retrieval Agent**: Responsible for fetching the top 20 matching records.
# - **LLM**: Utilizes a re-ranking algorithm mechanism for resume score generation based on various factors.
# - **Top Resumes Selection**: Final selection process.
# - **Future Scope**: Includes a profile summary extraction agent.
#
# The flowchart shows the relationships and data flow between these components, emphasizing the process of extracting and refining resume data for selection.
# Page Number: 2 | Page Content:
# ```
# pip install doctomarkdown
# ```
#
# ```python
# from doctomarkdown import DocToMarkdown
# from openai import OpenAI
# import os
# from dotenv import load_dotenv
# load_dotenv()
#
# client = OpenAI(
#     api_key=os.environ.get('OPENAI_API_KEY'),
# )
#
# app = DocToMarkdown(llm_client=client,
#                     llm_model='gpt-4o')
#
# result = app.convert_pptx_to_markdown(
#     filepath="sample_docs/sample_ppt_2.pptx",
#     extract_images=True,
#     extract_tables=True,
#     output_path="markdown_output"
# )
#
# for page in result.pages:
#     print(f"Page Number: {page.page_number} | Page Content: {page.page_content}")
# ```
#
# **Note:** The image contains a code snippet for converting PowerPoint files to Markdown using the `doctomarkdown` library and OpenAI's API. The code initializes the OpenAI client, sets up the `DocToMarkdown` application, and processes a PowerPoint file to extract images and tables, outputting the results to a specified directory.

# %%
from doctomarkdown import DocToMarkdown
from openai import OpenAI
import os
from dotenv import load_dotenv
load_dotenv()

app = DocToMarkdown()

result = app.convert_pptx_to_markdown(
    filepath="sample_docs/sample_ppt.pptx",
    extract_images=True,
    extract_tables=True,
    output_path="markdown_output"
)

for page in result.pages:
    print(f"Page Number: {page.page_number} | Page Content: {page.page_content}")
# Out:
# Page Number: 1 | Page Content: Professional PowerPoint
