# %% [markdown]
# # Numerical validation of controllability of ansatze in Larocca et al., *Quantum* 6 824 (2022)

# %%
import os
import logging
import time
import numpy as np
import h5py
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt

from fastdla.lie_closure import lie_closure
from fastdla.generators.hea import hea_generators
from fastdla.generators.spin_glass import spin_glass_generators
from fastdla.generators.heisenberg_hva import xxz_hva_generators
from fastdla.generators.tfim_hva import tfim_1d_hva_generators
from fastdla.generators.spin_chain import (magnetization_eigenspace, parity_eigenspace,
                                           translation_eigenspace, spin_flip_eigenspace)

logging.basicConfig(level=logging.WARNING)
logging.getLogger('fastdla').setLevel(logging.INFO)
LOG = logging.getLogger('fastdla')
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
jax.config.update('jax_enable_x64', True)

# %%
data_file = '/data/iiyama/test.h5'
force_rewrite = False
representation = 'matrix'
max_workers = 110
algorithm = 'default'

# %%
if data_file and not os.path.exists(data_file):
    with h5py.File(data_file, 'w'):
        pass

if representation == 'sparse':
    lc_kwargs = {'max_workers': max_workers}
elif representation == 'matrix':
    lc_kwargs = {'algorithm': algorithm}

# %% [markdown]
# ### Hardware efficient ansatz
#
# $$
# \mathcal{G}_{\mathrm{HEA}} = \left\{ X_n, Y_n \right\}_{n=0}^{N_q-1} \cup
#                                      \left\{ \sum_{n=0}^{N_q - 2} Z_n Z_{n+1} \right\}
# $$

# %%
run_calc = True
if data_file and not force_rewrite:
    with h5py.File(data_file, 'r') as source:
        if 'hea' in source:
            run_calc = False
            group = source['hea']
            nqs = group['num_qubits'][()]
            dla_dims = group['dla_dims'][()]

# if run_calc:
if True:
    min_nq = 4
    max_nq = 5
    nqs = np.arange(min_nq, max_nq + 1)
    dla_dims = []
    runtimes = []

    generators = hea_generators(num_qubits=2)
    if representation == 'matrix':
        generators = generators.to_matrices()
    dla = lie_closure(generators)

    for num_qubits in nqs:
        LOG.info('num_qubits=%d', num_qubits)
        start = time.time()
        generators = hea_generators(num_qubits=num_qubits)
        if representation == 'matrix':
            generators = generators.to_matrices()
        dla = lie_closure(generators, implementation=implementation)
        dla = lie_closure(generators, max_workers=110)
        runtime = time.time() - start
        LOG.info('DLA dimension %d (%.2f seconds)', dla.shape[0], runtime)
        dla_dims.append(dla.shape[0])
        runtimes.append(runtime)

    if data_file:
        with h5py.File(data_file, 'a') as out:
            if 'hea' in out:
                del out['hea']

            group = out.create_group('hea')
            group.create_dataset('num_qubits', data=nqs)
            group.create_dataset('dla_dims', data=dla_dims)
            group.create_dataset('runtimes', data=runtimes)
# Out:
# INFO:fastdla._lie_closure_impl.sparse_numba:Starting with 10 commutators..
# INFO:fastdla._lie_closure_impl.sparse_numba:Current Lie algebra dimension: 5
# INFO:fastdla._lie_closure_impl.sparse_numba:Evaluating 2/10 commutators for independence
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [1, 0] (0/1). Lie algebra dim 5
# INFO:fastdla._lie_closure_impl.sparse_numba:Adding 5 commutators; 13 more to be evaluated
# INFO:fastdla._lie_closure_impl.sparse_numba:Current Lie algebra dimension: 6
# INFO:fastdla._lie_closure_impl.sparse_numba:Evaluating 13/13 commutators for independence
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [5, 1] (0/7). Lie algebra dim 6
# INFO:fastdla._lie_closure_impl.sparse_numba:Adding 40 commutators; 40 more to be evaluated
# INFO:fastdla._lie_closure_impl.sparse_numba:Current Lie algebra dimension: 11
# INFO:fastdla._lie_closure_impl.sparse_numba:Evaluating 35/40 commutators for independence
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [10, 4] (0/22). Lie algebra dim 11
# INFO:fastdla:num_qubits=4
# INFO:fastdla._lie_closure_impl.sparse_numba:Starting with 36 commutators..
# INFO:fastdla._lie_closure_impl.sparse_numba:Current Lie algebra dimension: 9
# INFO:fastdla._lie_closure_impl.sparse_numba:Evaluating 32/36 commutators for independence
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [1, 0] (0/8). Lie algebra dim 9
# INFO:fastdla._lie_closure_impl.sparse_numba:Adding 100 commutators; 104 more to be evaluated
# INFO:fastdla._lie_closure_impl.sparse_numba:Current Lie algebra dimension: 17
# INFO:fastdla._lie_closure_impl.sparse_numba:Evaluating 104/104 commutators for independence
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [14, 8] (0/42). Lie algebra dim 17
# INFO:fastdla._lie_closure_impl.sparse_numba:Adding 567 commutators; 567 more to be evaluated
# INFO:fastdla._lie_closure_impl.sparse_numba:Current Lie algebra dimension: 38
# INFO:fastdla._lie_closure_impl.sparse_numba:Evaluating 567/567 commutators for independence
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [24, 14] (0/311). Lie algebra dim 38
# INFO:fastdla._lie_closure_impl.sparse_numba:Adding 5292 commutators; 5292 more to be evaluated
# INFO:fastdla._lie_closure_impl.sparse_numba:Current Lie algebra dimension: 110
# INFO:fastdla._lie_closure_impl.sparse_numba:Evaluating 4647/5292 commutators for independence
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [43, 42] (0/2610). Lie algebra dim 110
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [58, 24] (500/2610). Lie algebra dim 114
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [59, 27] (1000/2610). Lie algebra dim 123
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [102, 90] (1500/2610). Lie algebra dim 179
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [102, 59] (2000/2610). Lie algebra dim 242
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [70, 45] (2500/2610). Lie algebra dim 252
# INFO:fastdla:DLA dimension 255 (0.51 seconds)
# INFO:fastdla:num_qubits=5
# INFO:fastdla._lie_closure_impl.sparse_numba:Starting with 55 commutators..
# INFO:fastdla._lie_closure_impl.sparse_numba:Current Lie algebra dimension: 11
# INFO:fastdla._lie_closure_impl.sparse_numba:Evaluating 55/55 commutators for independence
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [1, 0] (0/15). Lie algebra dim 11
# INFO:fastdla._lie_closure_impl.sparse_numba:Adding 270 commutators; 270 more to be evaluated
# INFO:fastdla._lie_closure_impl.sparse_numba:Current Lie algebra dimension: 26
# INFO:fastdla._lie_closure_impl.sparse_numba:Evaluating 268/270 commutators for independence
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [11, 1] (0/93). Lie algebra dim 26
# INFO:fastdla._lie_closure_impl.sparse_numba:Adding 2090 commutators; 2092 more to be evaluated
# INFO:fastdla._lie_closure_impl.sparse_numba:Current Lie algebra dimension: 70
# INFO:fastdla._lie_closure_impl.sparse_numba:Evaluating 2092/2092 commutators for independence
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [31, 13] (0/1087). Lie algebra dim 70
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [58, 36] (500/1087). Lie algebra dim 166
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [51, 41] (1000/1087). Lie algebra dim 316
# INFO:fastdla._lie_closure_impl.sparse_numba:Adding 57616 commutators; 57616 more to be evaluated
# INFO:fastdla._lie_closure_impl.sparse_numba:Current Lie algebra dimension: 347
# INFO:fastdla._lie_closure_impl.sparse_numba:Evaluating 57584/57616 commutators for independence
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [222, 79] (0/34334). Lie algebra dim 347
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [137, 130] (500/34334). Lie algebra dim 350
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [88, 33] (1000/34334). Lie algebra dim 355
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [97, 13] (1500/34334). Lie algebra dim 358
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [101, 27] (2000/34334). Lie algebra dim 361
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [207, 86] (2500/34334). Lie algebra dim 365
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [92, 18] (3000/34334). Lie algebra dim 369
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [166, 126] (3500/34334). Lie algebra dim 376
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator [163, 32] (4000/34334). Lie algebra dim 390
# INFO:fastdla._lie_closure_impl.sparse_numba:Processing commutator
plt.yscale('log')
plt.title('Hardware-efficient ansatz')
plt.xlabel('$N_q$', fontsize=16)
plt.xticks(nqs, labels=[f'{i}' for i in nqs])
plt.legend(fontsize=14);

# %% [markdown]
# ### Spin glass

# %%
run_calc = True
if data_file and not force_rewrite:
    with h5py.File(data_file, 'r') as source:
        if 'spin_glass' in source:
            run_calc = False
            group = source['spin_glass']
            nqs = group['num_qubits'][()]
            dla_dims = group['dla_dims'][()]

if run_calc:
    min_nq = 3
    max_nq = 6
    nqs = np.arange(min_nq, max_nq + 1)
    dla_dims = []
    runtimes = []

    for num_qubits in nqs:
        LOG.info('num_qubits=%d', num_qubits)
        start = time.time()
        generators = spin_glass_generators(num_qubits=num_qubits).to_matrices()
        dla = lie_closure(generators, implementation=algorithm)
        runtime = time.time() - start
        LOG.info('DLA dimension %d (%.2f seconds)', dla.shape[0], runtime)
        dla_dims.append(dla.shape[0])
        runtimes.append(runtime)

    if data_file:
        with h5py.File(data_file, 'a') as out:
            if 'spin_glass' in out:
                del out['spin_glass']

            group = out.create_group('spin_glass')
            group.create_dataset('num_qubits', data=nqs)
            group.create_dataset('dla_dims', data=dla_dims)
            group.create_dataset('runtimes', data=runtimes)

# %%
x = np.linspace(nqs[0], nqs[-1], 100)
plt.plot(x, (2 ** x) ** 2 - 1, label='$(2^{N_q})^2-1$')
plt.scatter(nqs, dla_dims, label=r'$dim(\mathfrak{g})$')
plt.yscale('log')
plt.title('Spin glass ansatz')
plt.xlabel('$N_q$', fontsize=16)
plt.xticks(nqs, labels=[f'{i}' for i in nqs])
plt.legend(fontsize=14);

# %% [markdown]
# ### $XXZ$ model (subspace controllable)

# %%
run_calc = True
if data_file and not force_rewrite:
    with h5py.File(data_file, 'r') as source:
        if 'xxz' in source:
            run_calc = False
            group = source['xxz']
            nspins = group['num_spins'][()]
            subspace_dims = group['subspace_dims'][()]
            dla_dims = group['dla_dims'][()]

if run_calc:
    min_nspin = 4
    max_nspin = 10
    nspins = np.arange(min_nspin, max_nspin + 1, 2)
    parity = 1
    subspace_dims = np.zeros((nspins.shape[0], max_nspin // 2 + 1), dtype=int)
    dla_dims = np.zeros((nspins.shape[0], max_nspin // 2 + 1), dtype=int)
    runtimes = np.zeros((nspins.shape[0], max_nspin // 2 + 1), dtype=float)

    for ispin, num_qubits in enumerate(nspins):
        LOG.info('num_spins=%d', num_qubits)
        generators = xxz_hva_generators(num_qubits).to_matrices()
        parity_subspace = parity_eigenspace(parity, num_spins=num_qubits, npmod=jnp)
        for imag, magnetization in enumerate(range(0, num_qubits + 1, 2)):
            LOG.info('magnetization=%d', magnetization)
            subspace = magnetization_eigenspace(magnetization, basis=parity_subspace, npmod=jnp)
            LOG.info('Subspace dimension %d', subspace.shape[1])
            generators_reduced = jnp.einsum('ij,gik,kl->gjl', subspace.conjugate(), generators,
                                            subspace)
            start = time.time()
            dla = lie_closure(generators_reduced, implementation=algorithm)
            runtime = time.time() - start
            LOG.info('DLA dimension %d (%.2f seconds)', dla.shape[0], runtime)
            subspace_dims[ispin, imag] = subspace.shape[1]
            dla_dims[ispin, imag] = dla.shape[0]
            runtimes[ispin, imag] = runtime

            break

    if data_file:
        with h5py.File(data_file, 'a') as out:
            if 'xxz' in out:
                del out['xxz']

            group = out.create_group('xxz')
            group.create_dataset('num_spins', data=nspins)
            group.create_dataset('subspace_dims', data=subspace_dims)
            group.create_dataset('dla_dims', data=dla_dims)
            group.create_dataset('runtimes', data=runtimes)

# %%
from matplotlib.lines import Line2D

handles = [Line2D([0, 1], [0, 1], color='k'), Line2D([], [], color='k', linestyle='none', marker='o')]
labels = ['subspace $d^2$', r'$dim(\mathfrak{g})+1$']
for imag in range(nspins[-1] // 2 + 1):
    magnetization = imag * 2
    mask = nspins >= magnetization
    line, = plt.plot(nspins[mask], np.square(subspace_dims[mask][:, imag]))
    plt.scatter(nspins[mask], dla_dims[mask][:, imag] + 1)
    handles.append(line)
    labels.append(f'M={magnetization}')
plt.yscale('log')
plt.title('XXZ model HVA')
plt.xlabel('$N_q$', fontsize=16)
plt.xticks(nspins, labels=[f'{i}' for i in nspins])
plt.legend(handles, labels, fontsize=12);

# %% [markdown]
# ### TFIM HVA

# %%
run_calc = True
if data_file and not force_rewrite:
    with h5py.File(data_file, 'r') as source:
        if 'tfim' in source:
            run_calc = False
            group = source['tfim']
            nspins = group['num_spins'][()]
            dla_dims = group['dla_dims'][()]

if run_calc:
    min_nspin = 8
    max_nspin = 16
    nspins = np.arange(min_nspin, max_nspin + 1, 2)
    parity = 1
    z2_eigval = 1
    jphase = 0
    subspace_dims = np.zeros((nspins.shape[0], 2), dtype=int)
    dla_dims = np.zeros((nspins.shape[0], 2), dtype=int)
    runtimes = np.zeros((nspins.shape[0], 2), dtype=float)

    for ispin, num_qubits in enumerate(nspins):
        LOG.info('num_spins=%d', num_qubits)
        z2_subspace = spin_flip_eigenspace(z2_eigval, num_spins=num_qubits, npmod=jnp)
        for ibc, bc in enumerate(['open', 'periodic']):
            LOG.info('boundary condition: %s', bc)
            generators = tfim_1d_hva_generators(num_qubits, boundary_condition=bc).to_matrices()
            if bc == 'open':
                subspace = parity_eigenspace(parity, basis=z2_subspace, npmod=jnp)
            else:
                subspace = translation_eigenspace(jphase, basis=z2_subspace, npmod=jnp)
            LOG.info('Subspace dimension %d', subspace.shape[1])
            generators_reduced = jnp.einsum('ij,gik,kl->gjl', subspace.conjugate(), generators,
                                            subspace)
            start = time.time()
            dla = lie_closure(generators_reduced, implementation=algorithm)
            runtime = time.time() - start
            LOG.info('DLA dimension %d (%.2f seconds)', dla.shape[0], runtime)
            subspace_dims[ispin, ibc] = subspace.shape[1]
            dla_dims[ispin, ibc] = dla.shape[0]
            runtimes[ispin, ibc] = runtime

            break

    if data_file:
        with h5py.File(data_file, 'a') as out:
            if 'tfim' in out:
                del out['tfim']

            group = out.create_group('tfim')
            group.create_dataset('num_spins', data=nspins)
            group.create_dataset('dla_dims', data=dla_dims)
            group.create_dataset('runtimes', data=runtimes)

# %%
for ibc, bc in enumerate(['open', 'periodic']):
    plt.plot(nspins, subspace_dims[:, ibc], label=f'subspace dim ({bc})')
    plt.scatter(nspins, dla_dims[:, ibc], label=fr'$dim(\mathfrak{{g}}_{{{bc}}})$')

x = np.linspace(nspins[0], nspins[-1], 200)
plt.plot(x, np.square(x), color='k', linestyle='--', label='$n^2$')
plt.plot(x, 1.5 * x, color='k', linestyle=':', label='3n/2')
plt.title('Transverse Ising model HVA')
plt.xlabel('$N_q$', fontsize=16)
plt.xticks(nspins, labels=[f'{i}' for i in nspins])
plt.legend(fontsize=12);
