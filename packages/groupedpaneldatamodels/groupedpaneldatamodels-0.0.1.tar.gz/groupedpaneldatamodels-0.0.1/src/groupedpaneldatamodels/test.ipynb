# %%
from model import GroupedFixedEffects, GroupedInteractiveFixedEffects

import numpy as np

# %%
import pickle

example_data = pickle.load(open("dgp3-example-1749134059.pkl", "rb"))
example_data
# Out:
# (array([[[ 0.57045441,  1.23455846, -0.3239036 ],
#          [-0.53905788, -0.21120681, -0.27292028],
#          [-0.11281864, -0.38185688,  0.44283206],
#          ...,
#          [-0.40181503, -0.47544301,  1.52915006],
#          [-1.24328868, -0.54357582,  0.1948969 ],
#          [ 0.05957885,  0.46928181, -2.10179361]],
#
#         [[ 0.59971913,  2.51679173, -1.20159074],
#          [-0.17315466,  0.13636155,  0.53195634],
#          [ 1.32139781,  0.02123584, -0.16366859],
#          ...,
#          [-1.88439598,  0.44201129,  1.74954855],
#          [-1.68135648,  0.92096725,  0.839019  ],
#          [-0.04193948, -0.52721175,  1.43309157]],
#
#         [[-0.18502759,  0.79567845, -0.04027956],
#          [-0.39365183,  1.46334252, -0.13091558],
#          [ 0.98735108, -0.36212674, -0.2045839 ],
#          ...,
#          [ 0.44501734, -0.42969193,  1.77953817],
#          [ 0.06333887,  1.19673839, -0.48144891],
#          [-1.05433605,  0.18633158,  0.01315605]],
#
# ...

# %%
x_example = example_data[0]
y_example = np.reshape(example_data[1], (100, 50, 1))
f_example = example_data[2]
g_example = example_data[3]

# %%
t = GroupedFixedEffects(y_example, x_example, 3, model="bonhomme_manresa", use_bootstrap=True, entity_effects=False).fit(max_iter=100, gfe_iterations=10, tol=1e-6)
display(t.params)
display(t.params_standard_errors)
display(t.get_confidence_intervals(0.99))
# Out:
# /Users/michadenheijer/Documents/GitHub/paneldatamodels/src/groupedpaneldatamodels/models/bonhomme_manresa.py:273: RuntimeWarning: invalid value encountered in divide
#   alphas = sums / counts[:, None]  # broadcast counts over T
# 100%|██████████| 50/50 [00:03<00:00, 15.87it/s]
# {'beta': array([[1.00946636, 1.98219464, 2.97299043],
#         [0.9835662 , 1.99498001, 2.99209561],
#         [0.97442184, 2.01502848, 3.02936877]]),
#  'alpha': array([[ 1.94224763e-01,  4.00081521e-02, -6.43217982e-02,
#          -2.82511341e-02,  8.48512719e-02, -1.79973025e-01,
#           5.37166521e-02,  7.35190071e-02, -1.54961036e-01,
#           1.48720138e-01,  2.31677172e-01,  1.88406387e-02,
#           3.46196765e-02,  1.16581385e-01,  1.34278391e-01,
#          -1.52908951e-02, -5.33044940e-02, -3.95693373e-02,
#           2.35757684e-01, -5.63751774e-02, -6.95003498e-02,
#           1.41419149e-01,  4.28605675e-02,  6.27334577e-02,
# ...

# %%
from statsmodels import api as sm

# %%
x_example.reshape(-1, 3).shape
# Out:
# (5000, 3)

# %%
sm.OLS(y_example.reshape(-1, 1), sm.add_constant(x_example.reshape(-1, 3))).fit(cov_type="HC3").summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.756
# Model:                            OLS   Adj. R-squared:                  0.756
# Method:                 Least Squares   F-statistic:                     2302.
# Date:                Fri, 06 Jun 2025   Prob (F-statistic):               0.00
# Time:                        18:16:40   Log-Likelihood:                -9839.1
# No. Observations:                5000   AIC:                         1.969e+04
# Df Residuals:                    4996   BIC:                         1.971e+04
# Df Model:                           3
# Covariance Type:                  HC3
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0157      0.025     -0.641      0.522      -0.064       0.032
# ...
